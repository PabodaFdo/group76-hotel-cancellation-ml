# %% [markdown]
# # Member 1 — Dataset Structure
#
# Owner: IT24101668
#
# Purpose: Inspect and document the structure of the Hotel Booking Demand dataset.
#
# TODO: Begin this notebook during Phase 2 after the approved dataset has been added.
